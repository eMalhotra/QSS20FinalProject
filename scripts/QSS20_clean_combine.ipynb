# %%
import pandas as pd
import numpy as np

half1 = pd.read_csv("/Users/vprincess/Desktop/QSS20Projects/311_2012-2019.csv")
half2 = pd.read_csv("/Users/vprincess/Desktop/QSS20Projects/311_2020-2022.csv")

half1.head()
half2.head()
# Out:
# /var/folders/yp/gwv1rwds4xs209wcm4jtxf6m0000gn/T/ipykernel_67218/3565729074.py:4: DtypeWarning: Columns (9,34,37,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   half1 = pd.read_csv("/Users/vprincess/Desktop/QSS20Projects/311_2012-2019.csv")
# /var/folders/yp/gwv1rwds4xs209wcm4jtxf6m0000gn/T/ipykernel_67218/3565729074.py:5: DtypeWarning: Columns (21,37,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   half2 = pd.read_csv("/Users/vprincess/Desktop/QSS20Projects/311_2020-2022.csv")
#    Unique Key            Created Date             Closed Date Agency  \
# 0    56414482  12/31/2022 11:30:21 PM  01/01/2023 01:06:36 AM   NYPD
# 1    56418578  12/31/2022 11:18:00 PM  01/01/2023 01:07:10 AM   NYPD
# 2    56415500  12/31/2022 11:00:56 PM  01/01/2023 01:25:28 AM   NYPD
# 3    56419279  12/31/2022 10:59:10 PM  01/01/2023 01:25:14 AM   NYPD
# 4    56417625  12/31/2022 10:57:35 PM  01/01/2023 01:25:54 AM   NYPD
#
# ...

# %%
import pandas as pd

# Folder path
folder_path = "/Users/vprincess/Desktop/QSS20Projects/"

# Load datasets
df1 = pd.read_csv(folder_path + "311_2012-2019.csv")
df2 = pd.read_csv(folder_path + "311_2020-2022.csv")

# Append (stack rows)
combined_df = pd.concat([df1, df2], ignore_index=True)

# Save combined dataset
combined_df.to_csv(folder_path + "311_2012-2022_combined.csv", index=False)

print("Datasets successfully combined and saved.")
# Out:
# /var/folders/yp/gwv1rwds4xs209wcm4jtxf6m0000gn/T/ipykernel_67218/15152781.py:7: DtypeWarning: Columns (9,34,37,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(folder_path + "311_2012-2019.csv")
# /var/folders/yp/gwv1rwds4xs209wcm4jtxf6m0000gn/T/ipykernel_67218/15152781.py:8: DtypeWarning: Columns (21,37,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(folder_path + "311_2020-2022.csv")
# Datasets successfully combined and saved.

# %%
# Folder path
folder_path = "/Users/vprincess/Desktop/QSS20Projects/"

# Load combined dataset
df = pd.read_csv(folder_path + "311_2012-2022_combined.csv")

# List of columns to drop
cols_to_drop = [
    "Agency",
    "Vehicle Type",
    "Taxi Company Borough",
    "Taxi Pick Up Location",
    "Bridge Highway Name",
    "Bridge Highway Direction",
    "Road Ramp",
    "Bridge Highway Segment",
    "Location"
    "Incident Address",
    "Street Name",
    "Cross Street 1",
    "Cross Street 2",
    "Intersection Street 1",
    "Intersection Street 2",
    "Address Type",
    "City",
    "Landmark",
    "Facility Type",
    "Due Date",
    "Community Board",
    "Borough",
    "X Coordinate (State Plane)",
    "Y Coordinate (State Plane)",
    "Park Facility Name",
    "Park Borough",
    "Resolution Action Updated Date"
    "Incident Address"
]

# Drop columns (only if they exist to avoid errors)
df = df.drop(columns=[col for col in cols_to_drop if col in df.columns])

# Save cleaned dataset
df.to_csv(folder_path + "311_2012-2022_cleaned.csv", index=False)

print("Columns dropped and cleaned dataset saved.")
# Out:
# /var/folders/yp/gwv1rwds4xs209wcm4jtxf6m0000gn/T/ipykernel_67218/376374042.py:5: DtypeWarning: Columns (9,21,29,30,34,37,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(folder_path + "311_2012-2022_combined.csv")
# Columns dropped and cleaned dataset saved.
